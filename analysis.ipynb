# %%
from data.flights import flights
from bokeh.charts import output_notebook, show
from bokeh.charts import Histogram, BoxPlot
from bokeh.models.widgets.tables import DataTable, TableColumn, NumberFormatter
from bokeh.models import ColumnDataSource

# %% [raw]
# <script>
#     var code_show=true; //true -> hide code at first
#
#     function code_toggle() {
#         $('div.prompt').hide(); // always hide prompt
#
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
# </script>

# %% [markdown]
# # Which Paper Airplane Flies the Furthest?
# ** By Paige and Charlotte Caraway **
#
# ![image](https://www.evernote.com/l/ANqhL2jxgmtFaYhsuMldrEZNIwm_yCQt19QB/image.jpg)

# %%
output_notebook(hide_banner=True)

# %% [markdown]
# ## Overall Results

# %%
boxes = BoxPlot(flights, values='distance (ft)', color='type', label='type')
show(boxes)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3635ca7f-c03a-43dd-a3cd-085a3df4e08e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# ## Model: Dart
# ![image](https://www.evernote.com/l/ANq56FIF5O9CYbZRdFBadZm94AK5sbJjFFgB/image.jpg)

# %% [markdown]
# ### Flight Data

# %%
dart_flights = flights[flights['type'] == 'dart']
columns = [
    TableColumn(field='id', title='ID'),
    TableColumn(field='type', title='Model'),
    TableColumn(field='distance (ft)', title='Distance (feet)', formatter=NumberFormatter(format='0,0.00', rounding='round'))
]

dart_table = DataTable(source=ColumnDataSource(dart_flights), columns=columns)
show(dart_table)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="73621c09-d5b9-4279-b465-476b5baf6e03"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
dart_plot = Histogram(dart_flights, title="Dart Flight distance", values="distance (ft)", bins=list(range(10, 32, 2)))
show(dart_plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="57de86ba-c961-4217-8e48-b120581013ad"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# ## Model: Coaster
#
# ![mantis model](https://www.evernote.com/l/ANqJWnTnIRVL6Yz714TlPGWF2nox2lPWZjUB/image.jpg)

# %% [markdown]
# ### Flight Data

# %%
coaster_flights = flights[flights['type'] == 'coasters']
coaster_table = DataTable(source=ColumnDataSource(coaster_flights), columns=columns)
show(coaster_table)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ddf846d0-bbb4-4df6-a4a5-c9c35699d327"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
coaster_plot = Histogram(coaster_flights, title="Coaster Flight distance", values="distance (ft)", bins=list(range(2, 14, 2)))
show(coaster_plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6a238a4-58bb-4c13-9434-ebbe65fc36aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# ## Model: Mantis
# ![coaster image](https://www.evernote.com/l/ANpZyYgLAk5Nya0nVyAU7mI6qangpDIcxe8B/image.jpg)

# %% [markdown]
# ### Flight Data

# %%
mantis_flights = flights[flights['type'] == 'mantis']
mantis_table = DataTable(source=ColumnDataSource(mantis_flights), columns=columns)
show(mantis_table)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8597ebf5-09d3-4252-92f4-772655d81efe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
mantis_flights = flights[flights['type'] == 'mantis']
mantis_plot = Histogram(mantis_flights, title="Mantis Flight distance", values="distance (ft)", bins=list(range(8,22,2)))
show(mantis_plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6982df2f-436c-4c08-ab43-34f455aa1035"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# ## Model: Shuttle
# ![shuttle image](https://www.evernote.com/l/ANqmVxKFK-ZBfYKKiGrhL4R8rodgIltbVjYB/image.jpg)

# %% [markdown]
# ### Flight Data

# %%
shuttle_flights = flights[flights['type'] == 'shuttle']
shuttle_table = DataTable(source=ColumnDataSource(shuttle_flights), columns=columns)
show(shuttle_table)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="60e69297-fa31-4558-ba60-0911e82640f8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
shuttle_plot = Histogram(shuttle_flights, title="Shuttle Flight distance", values="distance (ft)", bins=list(range(4, 20, 2)))
show(shuttle_plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="22f6e4bc-884c-42e6-ab3e-3080fda725c3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
